# %% [markdown]
# # **Pandas (Day-1)**

# %%
# import libraries
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
# read the csv file dataset
df = pd.read_csv("../Datasets/population_of_pakistan.csv")
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# write the data to a excel file
df.to_excel("../Datasets/population_of_pakistan.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # write the data to a excel file
# ----> 2 df.to_excel("../Datasets/population_of_pakistan.xlsx",index=False)
#
# File c:\Users\sumit\.conda\envs\TF_ENV\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Pandas tips

# %%
print(df)
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
df.head(10)
# Out:
#   PROVINCE             DIVISION               DISTRICT  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 5   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 6   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 7   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 8   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 9   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
#
#                SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0       BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1          CHISHTIAN TEHSIL        1500.0             540342        273788
# 2         FORT ABBAS TEHSIL        2536.0             361240        182655
# ...

# %%
df.tail(10)
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 518  KPK/FATA             KOHAT DIVISION           ORAKZAI DISTRICT
# 519  KPK/FATA             KOHAT DIVISION           ORAKZAI DISTRICT
# 520  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 521  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 522  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 518       LOWER TEHSIL         565.0             107323         53767
# 519       UPPER TEHSIL         299.0              63885         32299
# ...

# %%
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
area = 18374.0
for i in range(len(df)):
    if df["AREA (sq.km)"][i] == area:
        print(df.loc[i])
# Out:
# PROVINCE                                   PUNJAB
# DIVISION                      BAHAWALPUR DIVISION
# DISTRICT                      BAHAWALPUR DISTRICT
# SUB DIVISION                        YAZMAN TEHSIL
# AREA (sq.km)                              18374.0
# ALL SEXES (RURAL)                          564422
# MALE (RURAL)                               288761
# FEMALE (RURAL)                             275612
# TRANSGENDER (RURAL)                            49
# SEX RATIO (RURAL)                          104.77
# AVG HOUSEHOLD SIZE (RURAL)                   6.41
# POPULATION 1998 (RURAL)                    385770
# ANNUAL GROWTH RATE (RURAL)                   2.02
# ALL SEXES (URBAN)                           48883
# MALE (URBAN)                                24884
# FEMALE (URBAN)                              23995
# TRANSGENDER (URBAN)                             4
# SEX RATIO (URBAN)                           103.7
# AVG HOUSEHOLD SIZE (URBAN)                   6.18
# ...

# %%
df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
df.astype({"MALE (URBAN)" : "object"}).dtypes
# df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                   object
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
df1 = df.sample(frac=0.5,random_state=1)
df2 = df.drop(df1.index)

# %%
df.nunique()
# Out:
# PROVINCE                        5
# DIVISION                       28
# DISTRICT                      131
# SUB DIVISION                  528
# AREA (sq.km)                  466
# ALL SEXES (RURAL)             495
# MALE (RURAL)                  495
# FEMALE (RURAL)                495
# TRANSGENDER (RURAL)            82
# SEX RATIO (RURAL)             435
# AVG HOUSEHOLD SIZE (RURAL)    277
# POPULATION 1998 (RURAL)       507
# ANNUAL GROWTH RATE (RURAL)    275
# ALL SEXES (URBAN)             373
# MALE (URBAN)                  372
# FEMALE (URBAN)                373
# TRANSGENDER (URBAN)            93
# SEX RATIO (URBAN)             340
# AVG HOUSEHOLD SIZE (URBAN)    222
# POPULATION 1998 (URBAN)       335
# ANNUAL GROWTH RATE (URBAN)    233
# dtype: int64

# %%
# df = pd.read_csv('../Datasets/population_of_pakistan.csv')

df.dict_to
