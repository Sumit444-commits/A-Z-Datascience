# %% [markdown]
# # blockchain
#  Block chain is a distributed database that maintains a continuously growing list of records, called blocks, secured from tampering and revision. Each block contains a timestamp and a link to a previous block. By design, blockchains are inherently resistant to modification of the data. Once recorded, the data in any given block cannot be altered without the alteration of all subsequent blocks, which requires the consensus of the network majority.
#
# # blockchain technology
#
# Blockchain technology is a decentralized solution to tracking, documenting, and facilitating transactions. It is a distributed ledger that is completely open to anyone. They have an interesting property: once some data is recorded inside a blockchain, it becomes very difficult to change it. So, how does it work?
#
# # How does blockchain work?
#
# A blockchain is a chain of blocks that contain data or information. The data is stored inside the block in a specific way. When a new block is added to the chain, it is linked to the previous block using a cryptographic hash of the previous block. This is what makes the blockchain secure and tamper-proof.
#
# # What is a hash?
#
# A hash is a function that converts an input (or 'message') into a fixed-size string of bytes. The output, which is a hash, is usually a string of numbers and letters. The hash is unique to the input. If the input changes even slightly, the hash will change completely.
#
# # How does a blockchain store data?
#
# A blockchain stores data in blocks. Each block contains a list of transactions, a timestamp, and a hash of the previous block. The hash is what links the blocks together. When a new block is added to the chain, it is linked to the previous block using the hash of the previous block.
#
# # What is a blockchain used for?
#
# Blockchains are used for a variety of applications. They are most commonly used for cryptocurrencies, such as Bitcoin. However, they can also be used for other applications, such as supply chain management, voting systems, and more.
#
# # Conclusion
#
# Blockchain technology is a decentralized solution to tracking, documenting, and facilitating transactions. It is a distributed ledger that is completely open to anyone. They have an interesting property: once some data is recorded inside a blockchain, it becomes very difficult to change it. This makes blockchains secure and tamper-proof.
#
# ![image.png](attachment:image.png)
#
# - Hash value: 64 bit hex value
# - ph: previous hash (to link the blocks)
# - data: data stored in the block
# - Nonce: random number used in cryptography
# - Timestamp: time when the block is created
# - Index: index of the block

# %% [markdown]
# In simple Block chain is
# - open ( open to all )
# - distributed ( no central authority )
# - ledger ( record of transactions )
# - efficient ( fast and secure )
# - verify ( verify the transaction e.g: validate the transaction )
# - permanent ( once added can't be changed )
